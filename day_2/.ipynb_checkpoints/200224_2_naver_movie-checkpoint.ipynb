# %%
from bs4 import BeautifulSoup  
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "http://movie.naver.com/"
url_syb = "movie/sdb/rank/rmovie.nhn?sel=cur&date=20200223"

page = urlopen(url_base+url_syb)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20200223" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %% [markdown]
# #### 영화 제목 리스트

# %%
# soup.find_all('div', 'tit5')
soup.find_all('div', class_='tit5')
# soup.find_all('div', {'class': 'tit5'})
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=181710" title="포드 V 페라리">포드 V 페라리</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=35901" title="살인의 추억">살인의 추억</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=189111" title="두 교황">두 교황</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=76667" title="울지마 톤즈">울지마 톤즈</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=185275" title="미안해요, 리키">미안해요, 리키</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=29059" title="피아니스트의 전설">피아니스트의 전설</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=187308" title="조조 래빗">조조 래빗</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=52515" title="인셉션">인셉션</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=152160" title="킹 오브 프리즘">킹 오브 프리즘</a>
#  </div>, <div class="tit5">
# ...

# %%
len(soup.find_all('div', class_='tit5'))
# Out:
# 43

# %%
soup.find_all('div', class_='tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=181710" title="포드 V 페라리">포드 V 페라리</a>
# </div>

# %%
soup.find_all('div', class_='tit5')[0].a.string
# soup.find_all('div', class_='tit5')[0].a.text
# Out:
# '포드 V 페라리'

# %% [markdown]
# #### 영화의 평점

# %%
soup.find_all('td', class_='point')
# Out:
# [<td class="point">9.51</td>,
#  <td class="point">9.40</td>,
#  <td class="point">9.36</td>,
#  <td class="point">9.34</td>,
#  <td class="point">9.28</td>,
#  <td class="point">9.25</td>,
#  <td class="point">9.24</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.17</td>,
#  <td class="point">9.12</td>,
#  <td class="point">9.12</td>,
#  <td class="point">9.11</td>,
#  <td class="point">9.08</td>,
#  <td class="point">9.03</td>,
#  <td class="point">9.02</td>,
#  <td class="point">8.94</td>,
#  <td class="point">8.92</td>,
#  <td class="point">8.89</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.80</td>,
#  <td class="point">8.70</td>,
#  <td class="point">8.66</td>,
#  <td class="point">8.61</td>,
#  <td class="point">8.53</td>,
#  <td class="point">8.50</td>,
#  <td class="point">8.50</td>,
#  <td class="point">8.42</td>,
#  <td class="point">8.40</td>,
#  <td class="point">8.26</td>,
#  <td class="point">7.99</td>,
#  <td class="point">7.98</td>,
# ...

# %%
num_of_movie = len(soup.find_all('td', 'point'))

# %%
soup.find_all('td', class_='point')[0].string
# Out:
# '9.51'

# %%
num_of_movie
# Out:
# 43

# %%
# movie_name = [soup.find_all('div', class_='tit5')[i].a.string for i in range(num_of_movie)]

# %%
# 위의 코드와 동일한 내용입니다. (list comprehension)
movie_name = []
for i in range(num_of_movie):
    movie = soup.find_all('div', class_='tit5')[i].a.string
    movie_name.append(movie)

# %%
movie_name
# Out:
# ['포드 V 페라리',
#  '살인의 추억',
#  '두 교황',
#  '울지마 톤즈',
#  '미안해요, 리키',
#  '피아니스트의 전설',
#  '조조 래빗',
#  '인셉션',
#  '킹 오브 프리즘',
#  '킹 오브 프리즘 프라이드 더 히어로',
#  '나이브스 아웃',
#  '러브레터',
#  '결혼 이야기',
#  '1917',
#  '타오르는 여인의 초상',
#  '윤희에게',
#  '극장판 원피스 스탬피드',
#  '작은 아씨들',
#  '벌새',
#  '아이리시맨',
#  '겨울왕국 2',
#  '조커',
#  '그녀에게',
#  '졸업',
#  '러브 라이브! 더 스쿨 아이돌 무비',
#  '기생충',
#  '수퍼 소닉',
#  '러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우',
#  '메기',
#  '라붐',
#  '설국열차',
#  '날씨의 아이',
#  '정직한 후보',
#  '원스 어폰 어 타임... 인 할리우드',
#  '철벽선생',
#  '남산의 부장들',
#  '지푸라기라도 잡고 싶은 짐승들',
#  '히트맨',
#  '클로젯',
#  '버즈 오브 프레이(할리 퀸의 황홀한 해방)',
#  '82년생 김지영',
#  '미스터 주: 사라진 VIP',
#  '킹 오브 프리즘 -샤이니 세븐 스타즈-']

# %%
movie_point = [soup.find_all('td', class_='point')[n].string for n in range(num_of_movie)]
movie_point
# Out:
# ['9.51',
#  '9.40',
#  '9.36',
#  '9.34',
#  '9.28',
#  '9.25',
#  '9.24',
#  '9.22',
#  '9.17',
#  '9.12',
#  '9.12',
#  '9.11',
#  '9.08',
#  '9.03',
#  '9.02',
#  '8.94',
#  '8.92',
#  '8.89',
#  '8.81',
#  '8.80',
#  '8.70',
#  '8.66',
#  '8.61',
#  '8.53',
#  '8.50',
#  '8.50',
#  '8.42',
#  '8.40',
#  '8.26',
#  '7.99',
#  '7.98',
#  '7.91',
#  '7.73',
#  '7.65',
#  '7.65',
#  '7.43',
#  '7.16',
#  '7.14',
#  '6.87',
#  '6.72',
#  '6.69',
#  '4.47',
#  '2.09']

# %%
import datetime

days_range = []

start = datetime.datetime.strptime("2019-10-1", "%Y-%m-%d")  # 수집 시작 날짜
end = datetime.datetime.strptime("2020-02-1", "%Y-%m-%d")  # 수집 종료 날짜 + 1
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end - start).days)]

for date in date_generated:
    days_range.append(date.strftime("%Y-%m-%d"))

# %%
days_range
# Out:
# ['2019-10-01',
#  '2019-10-02',
#  '2019-10-03',
#  '2019-10-04',
#  '2019-10-05',
#  '2019-10-06',
#  '2019-10-07',
#  '2019-10-08',
#  '2019-10-09',
#  '2019-10-10',
#  '2019-10-11',
#  '2019-10-12',
#  '2019-10-13',
#  '2019-10-14',
#  '2019-10-15',
#  '2019-10-16',
#  '2019-10-17',
#  '2019-10-18',
#  '2019-10-19',
#  '2019-10-20',
#  '2019-10-21',
#  '2019-10-22',
#  '2019-10-23',
#  '2019-10-24',
#  '2019-10-25',
#  '2019-10-26',
#  '2019-10-27',
#  '2019-10-28',
#  '2019-10-29',
#  '2019-10-30',
#  '2019-10-31',
#  '2019-11-01',
#  '2019-11-02',
#  '2019-11-03',
#  '2019-11-04',
#  '2019-11-05',
#  '2019-11-06',
#  '2019-11-07',
#  '2019-11-08',
#  '2019-11-09',
#  '2019-11-10',
#  '2019-11-11',
#  '2019-11-12',
#  '2019-11-13',
#  '2019-11-14',
#  '2019-11-15',
#  '2019-11-16',
#  '2019-11-17',
#  '2019-11-18',
#  '2019-11-19',
#  '2019-11-20',
#  '2019-11-21',
#  '2019-11-22',
#  '2019-11-23',
#  '2019-11-24',
#  '2019-11-25',
#  '2019-11-26',
#  '2019-11-27',
# ...

# %%
import urllib
from tqdm import tqdm_notebook
import re

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(days_range):
    html = "http://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=" + re.sub('-', '', str(today))
    response = urlopen(html)
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', class_='point'))
    
    movie_date.extend([today for n in range(end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# <ipython-input-110-1afa5af2d42e>:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for today in tqdm_notebook(days_range):
# ...

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (4506, 4506, 4506)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie['date'] = movie['date'].astype('datetime64[ns]')
movie.head()
# Out:
#         date        name point
# 0 2019-10-01      사랑의 선물  9.64
# 1 2019-10-01         주전장  9.54
# 2 2019-10-01      안녕 베일리  9.46
# 3 2019-10-01         알라딘  9.39
# 4 2019-10-01  폴란드로 간 아이들  9.33

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4506 entries, 0 to 4505
# Data columns (total 3 columns):
# date     4506 non-null datetime64[ns]
# name     4506 non-null object
# point    4506 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 105.7+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4506 entries, 0 to 4505
# Data columns (total 3 columns):
# date     4506 non-null datetime64[ns]
# name     4506 non-null object
# point    4506 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 105.7+ KB

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.mean)
# movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#              point
# name
# 그린 북      9.610000
# 가버나움      9.590000
# 포드 V 페라리  9.572000
# 사랑의 선물    9.513333
# 주전장       9.502688

# %%
tmp = movie.query('name == ["82년생 김지영"]')
tmp = movie[movie['name'] == '82년생 김지영']
tmp
# Out:
#            date      name  point
# 872  2019-10-23  82년생 김지영   5.38
# 919  2019-10-24  82년생 김지영   5.63
# 967  2019-10-25  82년생 김지영   5.77
# 1013 2019-10-26  82년생 김지영   5.97
# 1059 2019-10-27  82년생 김지영   6.21
# ...         ...       ...    ...
# 4343 2020-01-04  82년생 김지영   6.69
# 4380 2020-01-05  82년생 김지영   6.69
# 4417 2020-01-06  82년생 김지영   6.69
# 4457 2020-01-07  82년생 김지영   6.69
# 4499 2020-01-08  82년생 김지영   6.69
#
# [72 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
movie_best.head(10)
# Out:
#              point
# name
# 교회오빠        927.18
# 벌새          890.56
# 주전장         883.75
# 기생충         831.42
# 조커          774.33
# 메기          743.81
# 날씨의 아이      558.24
# 엑시트         506.19
# 더 킹: 헨리 5세  503.46
# 가장 보통의 연애   493.28

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], 
                                         values=['point'])
movie_pivot.head()
