# %%
import konlpy.tag
import re

# %%
# http://news.naver.com/main/ranking/read.nhn?rankingType=popular_day&oid=001&aid=0010083362&date=20180514&type=1&rankingSectionId=100&rankingSeq=4
with open('naver_news.txt', 'r', encoding='utf8') as f:
    content = f.read()

# %%
# Text cleaning
filtered_content = content.replace('.', '').replace(',','').replace("'","").replace('·', ' ').replace('=','')

# %%
# Twitter has changed to Okt since 0.4.5
twitter = konlpy.tag.Twitter()
twitter_morphs = twitter.pos(filtered_content)
print(twitter_morphs)
# Out:
# /Users/jehoonchae/opt/anaconda3/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('北', 'Foreign'), ('단계', 'Noun'), ('적', 'Suffix'), ('조치', 'Noun'), ('요구', 'Noun'), ('…', 'Punctuation'), ('美', 'Foreign'), ('이행', 'Noun'), ('기간', 'Noun'), ('압축', 'Noun'), ('한', 'Josa'), ('큰', 'Verb'), ('거래', 'Noun'), ('원해', 'Adjective'), ('폼페이', 'Noun'), ('오', 'Noun'), ('볼턴', 'Noun'), ('연일', 'Noun'), ('美', 'Foreign'), ('밑그림', 'Noun'), ('소개', 'Noun'), ('…', 'Punctuation'), ('北', 'Foreign'), ('구체', 'Noun'), ('적', 'Suffix'), ('답변', 'Noun'), ('안해', 'Noun'), ('트럼프', 'Noun'), ('미', 'Adjective'), ('대통령', 'Noun'), ('과', 'Josa'), ('김정은', 'Noun'), ('북한', 'Noun'), ('국무위원', 'Noun'), ('장', 'Suffix'), ('[', 'Punctuation'), ('워싱턴', 'Noun'), ('DC', 'Alpha'), ('EPA', 'Alpha'), ('연합뉴스', 'Noun'), ('자료', 'Noun'), ('사진', 'Noun'), ('](', 'Punctuation'), ('서울', 'Noun'), ('연합뉴스', 'Noun'), (')', 'Punctuation'), ('조준형', 'Noun'), ('기자', 'Noun'), ('다음', 'Noun'), ('달', 'Noun'), ('12일', 'Number'), ('싱가포르', 'Noun'), ('에서의', 'Josa'), ('도널드', 'Noun'), ('트럼프', 'Noun'), ('대통령', 'Noun'), ('과', 'Josa'), ('김정은', 'Noun'), ('국무위원', 'Noun'), ('장', 'Suffix'), ('간', 'Noun'), ('세기', 'Noun'), ('의', 'Josa'), ('회담', 'Noun'), ('을', 'Josa'), ('앞둔', 'Verb'), ('가운데', 'Noun'), ('북미', 'Noun'), ('빅딜', 'Noun'), ('의', 'Josa'), ('윤곽', 'Noun'), ('이', 'Josa'), ('드러나고', 'Verb'), ('있다', 'Adjective'), ('밑그림', 'Noun'), ('은', 'Josa'), ('트럼프', 'Noun'), ('미', 'Adjective'), ('행정부', 'Noun'), ('의', 'Josa'), ('외교', 'Noun'), ('안보', 'Noun'), ('핵심', 'Noun'), ('인사', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('입', 'Noun'), ('을', 'Josa'), ('통해', 'Noun'), ('소개', 'Noun'), ('되고', 'Verb'), ('있으나', 'Adjective'), ('이', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('북한', 'Noun'), ('은', 'Josa'), ('구체', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('반응', 'Noun'), ('하지', 'Verb'), ('않고', 'Verb'), ('있다', 'Adjective'), ('지금', 'Noun'), ('까지', 'Josa'), ('나온', 'Verb'), ('이', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('발언', 'Noun'), ('을', 'Josa'), ('종합', 'Noun'), ('해보면', 'Verb'), ('북미', 'Noun'), ('빅딜', 'Noun'), ('의', 'Josa'), ('골자', 'Noun'), ('는', 'Josa'), ('트럼프', 'Noun'), ('대통령', 'Noun'), ('의', 'Josa'), ('첫', 'Noun'), ('임기', 'Noun'), ('사실', 'Noun'), ('상', 'Suffix'), ('마지막', 'Noun'), ('해인', 'Noun'), ('2020년', 'Number'), ('까지', 'Foreign'), ('북한', 'Noun'), ('이', 'Josa'), ('비핵화', 'Noun'), ('를', 'Josa'), ('달성', 'Noun'), ('하면', 'Verb'), ('미국', 'Noun'), ('은', 'Josa'), ('국제사회', 'Noun'), ('의', 'Josa'), ('대북', 'Noun'), ('투자', 'Noun'), ('와', 'Josa'), ('경협', 'Noun'), ('을', 'Josa'), ('막는', 'Verb'), ('각종', 'Noun'), ('제재', 'Noun'), ('를', 'Josa'), ('해제', 'Noun'), ('하고', 'Josa'), ('북미', 'Noun'), ('수교', 'Noun'), ('와', 'Josa'), ('평화협정', 'Noun'), ('을', 'Josa'), ('체결', 'Noun'), ('하는', 'Verb'), ('등', 'Noun'), ('의', 'Josa'), ('내용', 'Noun'), ('인', 'Josa'), ('것', 'Noun'), ('으로', 'Josa'), ('보인다', 'Verb'), ('트럼프', 'Noun'), ('행정부', 'Noun'), ('에선', 'Josa'), ('존', 'Noun'), ('볼턴', 'Noun'), ('백악관', 'Noun'), ('국가', 'Noun'), ('안보', 'Noun'), ('보좌', 'Noun'), ('관', 'Noun'), ('과', 'Josa'), ('마이크', 'Noun'), ('폼페이', 'Noun'), ('오', 'Noun'), ('국무장관', 'Noun'), ('이', 'Josa'), ('서로', 'Noun'), ('역할', 'Noun'), ('분담', 'Noun'), ('해', 'Verb'), ('대북', 'Noun'), ('메시지', 'Noun'), ('를', 'Josa'), ('날리고', 'Verb'), ('있다', 'Adjective'), ('볼턴', 'Noun'), ('보좌', 'Noun'), ('관', 'Noun'), ('이', 'Josa'), ('채찍', 'Noun'), ('을', 'Josa'), ('들고', 'Verb'), ('철저한', 'Adjective'), ('비핵화', 'Noun'), ('에', 'Josa'), ('방점', 'Noun'), ('을', 'Josa'), ('두고', 'Verb'), ('있다면', 'Adjective'), ('폼페이', 'Noun'), ('오', 'Noun'), ('장관', 'Noun'), ('은', 'Josa'), ('비핵화', 'Noun'), ('때', 'Noun'), ('제공', 'Noun'), ('할', 'Verb'), ('당근', 'Noun'), ('을', 'Josa'), ('제', 'Modifier'), ('시한', 'Noun'), ('다', 'Adverb'), ('우선', 'Noun'), ('볼턴', 'Noun'), ('보좌', 'Noun'), ('관', 'Noun'), ('은', 'Josa'), ('13일', 'Number'), ('(', 'Punctuation'), ('현지', 'Noun'), ('시간', 'Noun'), (')', 'Punctuation'), ('북한', 'Noun'), ('의', 'Josa'), ('영구', 'Noun'), ('적', 'Suffix'), ('이고', 'Josa'), ('검증', 'Noun'), ('가능하며', 'Adjective'), ('불가', 'Noun'), ('역적', 'Noun'), ('인', 'Josa'), ('비핵화', 'Noun'), ('(', 'Punctuation'), ('PVID', 'Alpha'), (')', 'Punctuation'), ('를 ...

# %%
komoran = konlpy.tag.Komoran()
komoran_morphs = komoran.pos(filtered_content)
print(komoran_morphs)
# Out:
# [('北', 'SH'), ('단계', 'NNG'), ('적', 'XSN'), ('조치', 'NNG'), ('요구', 'NNG'), ('…', 'SE'), ('美', 'SH'), ('이행', 'NNP'), ('기간', 'NNP'), ('압축', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('크', 'VA'), ('ㄴ', 'ETM'), ('거래', 'NNG'), ('원', 'NNB'), ('하', 'XSA'), ('아', 'EC'), ('폼페이', 'NNP'), ('오', 'NNP'), ('볼턴', 'NNP'), ('연일', 'NNG'), ('美', 'SH'), ('밑그림', 'NNG'), ('소개', 'NNG'), ('…', 'SE'), ('北', 'SH'), ('구체', 'NNG'), ('적', 'XSN'), ('답변', 'NNG'), ('안해', 'NNG'), ('트럼프', 'NNP'), ('미', 'NNP'), ('대통령', 'NNG'), ('과', 'JC'), ('김정은', 'NNP'), ('북한', 'NNP'), ('국무위원', 'NNP'), ('장', 'NNP'), ('[', 'SS'), ('워싱턴', 'NNP'), ('DC', 'NNP'), ('EPA', 'SL'), ('연합뉴스', 'NNP'), ('자료', 'NNG'), ('사진', 'NNP'), (']', 'SS'), ('(', 'SS'), ('서울', 'NNP'), ('연합뉴스', 'NNP'), (')', 'SS'), ('조', 'NR'), ('준형', 'NNP'), ('기자', 'NNG'), ('다음', 'NNG'), ('달', 'NNG'), ('12', 'SN'), ('일', 'NNB'), ('싱가포르', 'NNP'), ('에서', 'JKB'), ('의', 'JKG'), ('도널드 트럼프', 'NNP'), ('대통령', 'NNG'), ('과', 'JC'), ('김정은', 'NNP'), ('국무위원', 'NNP'), ('장', 'NNP'), ('간', 'NNB'), ('세기', 'NNG'), ('의', 'JKG'), ('회담', 'NNG'), ('을', 'JKO'), ('앞두', 'VV'), ('ㄴ', 'ETM'), ('가운데', 'NNG'), ('북미', 'NNP'), ('빅딜', 'NNP'), ('의', 'JKG'), ('윤곽', 'NNG'), ('이', 'JKS'), ('드러나', 'VV'), ('고', 'EC'), ('있', 'VV'), ('다', 'EC'), ('밑그림', 'NNG'), ('은', 'JX'), ('트럼프', 'NNP'), ('미', 'NNP'), ('행정부', 'NNG'), ('의', 'JKG'), ('외교', 'NNG'), ('안보', 'NNG'), ('핵심', 'NNG'), ('인사', 'NNG'), ('들', 'XSN'), ('의', 'JKG'), ('입', 'NNG'), ('을', 'JKO'), ('통하', 'VV'), ('아', 'EC'), ('소개', 'NNG'), ('되', 'XSV'), ('고', 'EC'), ('있', 'VV'), ('으나', 'EC'), ('이', 'NP'), ('에', 'JKB'), ('대하', 'VV'), ('아', 'EC'), ('북한', 'NNP'), ('은', 'JX'), ('구체', 'NNG'), ('적', 'XSN'), ('으로', 'JKB'), ('반응', 'NNG'), ('하', 'XSV'), ('지', 'EC'), ('않', 'VX'), ('고', 'EC'), ('있', 'VV'), ('다', 'EC'), ('지금', 'NNG'), ('까지', 'JX'), ('나오', 'VV'), ('ㄴ', 'ETM'), ('이', 'NP'), ('들', 'XSN'), ('의', 'JKG'), ('발언', 'NNG'), ('을', 'JKO'), ('종합', 'NNG'), ('해보면', 'NNP'), ('북미', 'NNP'), ('빅딜', 'NNP'), ('의', 'JKG'), ('골자', 'NNG'), ('는', 'JX'), ('트럼프', 'NNP'), ('대통령', 'NNG'), ('의', 'JKG'), ('첫', 'MM'), ('임기', 'NNG'), ('사실', 'NNG'), ('상', 'XSN'), ('마지막', 'NNG'), ('해인', 'NNP'), ('2020', 'SN'), ('년', 'NNB'), ('까지', 'JX'), ('북한', 'NNP'), ('이', 'JKS'), ('비핵화', 'NNP'), ('를', 'JKO'), ('달성', 'NNG'), ('하', 'XSV'), ('면', 'EC'), ('미국', 'NNP'), ('은', 'JX'), ('국제', 'NNG'), ('사회', 'NNG'), ('의', 'JKG'), ('대북', 'NNP'), ('투자', 'NNG'), ('와', 'JC'), ('경협', 'NNG'), ('을', 'JKO'), ('막', 'VV'), ('는', 'ETM'), ('각종', 'NNG'), ('제재', 'NNG'), ('를', 'JKO'), ('해제', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('북미', 'NNP'), ('수', 'NNB'), ('교와', 'NNP'), ('평화', 'NNG'), ('협정', 'NNG'), ('을', 'JKO'), ('체결', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('등', 'NNB'), ('의', 'JKG'), ('내용', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETM'), ('것', 'NNB'), ('으로', 'JKB'), ('보이', 'VV'), ('ㄴ다', 'EC'), ('트럼프', 'NNP'), ('행정부', 'NNG'), ('에서', 'JKB'), ('ㄴ', 'JX'), ('존', 'NNP'), ('볼턴', 'NNP'), ('백악관', 'NNP'), ('국가', 'NNG'), ('안보', 'NNG'), ('보좌관', 'NNG'), ('과', 'JC'), ('마이크', 'NNP'), ('폼페이', 'NNP'), ('오', 'NNP'), ('국무장관', 'NNP'), ('이', 'JKS'), ('서로', 'MAG'), ('역할', 'NNG'), ('분담', 'NNG'), ('하', 'XSV'), ('아', 'EC'), ('대북', 'NNP'), ('메시지', 'NNG'), ('를', 'JKO'), ('날리', 'VV'), ('고', 'EC'), ('있', 'VV'), ('다', 'EC'), ('볼턴', 'NNP'), ('보좌관', 'NNG'), ('이', 'JKS'), ('채찍', 'NNG'), ('을', 'JKO'), ('들', 'VV'), ('고', 'EC'), ('철저', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('비핵화', 'NNP'), ('에', 'JKB'), ('방점', 'NNP'), ('을', 'JKO'), ('두', 'VV'), ('고', 'EC'), ('있', 'VV'), ('다면', 'EC'), ('폼페이', 'NNP'), ('오', 'NNP'), ('장관', 'NNG'), ('은', 'JX'), ('비핵화', 'NNP'), ('때', 'NNG'), ('제공', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('당근', 'NNP'), ('을', 'JKO'), ('제시', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EC'), ('우선', 'MAG'), ('볼턴', 'NNP'), ('보좌관', 'NNG'), ('은', 'JX'), ('13', 'SN'), ('일', 'NNB'), ('(', 'SS'), ('현지', 'NNG'), ('시간', 'NNG'), (')', 'SS'), ('북한', 'NNP'), ('의', 'JKG'), ('영구', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('고', 'EC'), ('검증', 'NNP'), ('가능', 'XR'), ('하', 'XSA'), ('며', 'EC'), ('불', 'XPN'), ('가역', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('ㄴ', 'ETM'), ('비핵 ...

# %%
Noun_words = []
for word, pos in twitter_morphs:
    if pos == 'Noun':
        Noun_words.append(word)
print(Noun_words)
# Out:
# ['단계', '조치', '요구', '이행', '기간', '압축', '거래', '폼페이', '오', '볼턴', '연일', '밑그림', '소개', '구체', '답변', '안해', '트럼프', '대통령', '김정은', '북한', '국무위원', '워싱턴', '연합뉴스', '자료', '사진', '서울', '연합뉴스', '조준형', '기자', '다음', '달', '싱가포르', '도널드', '트럼프', '대통령', '김정은', '국무위원', '간', '세기', '회담', '가운데', '북미', '빅딜', '윤곽', '밑그림', '트럼프', '행정부', '외교', '안보', '핵심', '인사', '입', '통해', '소개', '이', '대해', '북한', '구체', '반응', '지금', '이', '발언', '종합', '북미', '빅딜', '골자', '트럼프', '대통령', '첫', '임기', '사실', '마지막', '해인', '북한', '비핵화', '달성', '미국', '국제사회', '대북', '투자', '경협', '각종', '제재', '해제', '북미', '수교', '평화협정', '체결', '등', '내용', '것', '트럼프', '행정부', '존', '볼턴', '백악관', '국가', '안보', '보좌', '관', '마이크', '폼페이', '오', '국무장관', '서로', '역할', '분담', '대북', '메시지', '볼턴', '보좌', '관', '채찍', '비핵화', '방점', '폼페이', '오', '장관', '비핵화', '때', '제공', '당근', '시한', '우선', '볼턴', '보좌', '관', '현지', '시간', '북한', '영구', '검증', '불가', '역적', '비핵화', '를', '위해', '북한', '우라늄', '농축', '플루토늄', '재', '처리', '능력', '제거', '한편', '핵무기', '폐기', '미국', '반출', '방안', '제시', '더욱이', '핵무기', '해체', '미국', '주도', '것임', '매우', '고', '핵무기', '원료', '플루토늄', '농축', '우라늄', '생산', '시설', '제거', '것', '북한', '보유', '핵무기', '조기', '폐기', '미국', '방안', '한마디', '미국', '손', '북한', '핵', '무장', '해제', '것', '요구', '것', '볼턴', '보좌', '관', '핵무기', '생화학', '무기', '거론', '대량', '살상', '무기', '를', '모두', '압박', '트럼프', '행정부', '북한', '보유', '핵', '미래', '핵', '모두', '파기', '조치', '시한', '정', '최근', '마이크', '폼페이', '오', '국무장관', '방북', '동행', '브라이언', '훅', '국무부', '선임', '정책', '기획', '관', '방송', '인터뷰', '북한', '의지', '트럼프', '대통령', '첫', '임기', '내인', '북한', '불가', '역적', '비핵화', '입장', '가운데', '북미', '정상회담', '북한', '핵', '무력', '핵심', '핵탄두', '핵물질', '대륙간탄도미사일', '중', '일부', '개월', '안', '북한', '밖', '반출', '방안', '논의', '중인', '것', '비핵화', '마지막', '단계', '폐기', '절차', '것', '예상', '온', '보유', '핵', '일부', '초장', '국외', '반출', '함', '비핵화', '진정', '보이', '것', '미국', '요구', '수', '그래픽', '북미', '정상회담', '주요', '의제', '서울', '연합뉴스', '박영석', '기자', '북한', '미국', '역사상', '첫', '정상회담', '다음', '달', '싱가포르', '린다', '폼페이', '오', '장관', '언론', '인터뷰', '미국', '대로', '북한', '비핵화', '이행', '면', '북한', '정권', '교체', '추구', '점도', '재차', '강조', '우리', '안전', '보장', '제공', '것', '말', '안전보장', '불가침', '의사', '서면', '확인', '북미', '수교', '및', '평화협정', '체결', '등', '것', '외교', '보고', '폼페이', '오', '장관', '만약', '우리', '비핵화', '제재', '완화', '그', '더', '것', '것', '라며', '경제', '인', '센티', '브', '측면', '대북', '제재', '해제', '플러스', '알파', '거론', '인도', '지원', '제외', '정부', '차원', '직접', '대북', '지원', '미국', '제', '국', '기업', '북한', '진출', '및', '투자', '각종', '미국', '독자', '제재', '해제', '함', '북한', '자본', '기술', '길', '뜻', '해석', '미국', '의사결정', '영향력', '활용', '국제통화기금', '과', '세계', '은행', '등', '대북', '융자', '사업', '롭', '수', '방안', '것', '트럼프', '행정부', '내', '북한', '대한', '정부', '차원', '지원', '거론', '주목', '폼페이', '오', '장관', '북미', '합의', '이행', '방식', '면', '북한', '주장', '단계', '동시', '해법', '대해', '당신', '를', '우리', '를', '방식', '이전', '방식', '계속', '고', '이행', '단계', '성과', '동시성', '배제', '수', '합의', '이행', '기간', '최대한', '압축', '함', '크게', '방식', '선호', '음', '시사', '것', '해석', '이', '방안', '우선', '북한', '동의', '요한', '또', '북한', '동의', '최대', '허들', '검증', '것', '예상', '북미', '간', '비핵화', '합의', '경우', '앞', '북한', '제출', '핵', '고서', '내용', '검증', '수준', '미신', '시설', '검증', '수', '합의', '이행', '일', '진통', '것', '게', '외교', '가의', '체적', '예상', '신범철', '아산', '정책', '연구원', '안보', '통일', '센터', '미국', '북한', '살상', '무기', '능력', '전체', '제거', '목표', '아래', '효율', '이행', '위', '우선', '순위', '설정', '것', '며', '북한', '비핵화', '의지', '실현', '접근', '생각', '고', '말', '신', '센터', '가장', '핵물질', '핵탄두', '미사일', '먼저', '제거', '그', '다음', '핵', '시설', '장비', '데이터', '인력', '기타', '대량', '살상', '무기', '등', '제거', '것', '모든', '위협', '이내', '제거', '수', '핵물질', '무기', '초기', '제거', '함', '북한', '제재', '해제', '비핵화', '이행', '지연', '사전', '차단', '주도', '유지', '방법', '강', '구한', '것', '평가', '고', '부연', '은닉', '우라늄', '농축', '프로그램', '과', '그것', '통해', '북한', '농축', '우라늄', '규모', '등', '대한', '미국', '국제사회', '의', '구심', '북한', '해소', '수', '빅딜', '이행', '여부', '및', '속도', '결정', '것', '북미', '회담', '파트너', '연합뉴스', '제공', '기사', '제보', '및', '문의', '내', '생활', '최신', '트렌드', '사진', '구매', '문의']

# %%
# 불용어 제거를 위한 별도의 사전 (list 변수) 구축
stopwords = ['연합뉴스', '서울', '기자']
unique_Noun_words = set(Noun_words)
for word in unique_Noun_words:
    if word in stopwords:
        while word in Noun_words: Noun_words.remove(word)

# %%
from collections import Counter
c = Counter(Noun_words) # input type should be a list of words (or tokens)
print(c)
k = 20
print(c.most_common(k)) # 빈도수 기준 상위 k개 단어 출력
# Out:
# Counter({'북한': 27, '것': 19, '미국': 13, '비핵화': 12, '이행': 9, '북미': 9, '트럼프': 8, '폼페이': 7, '오': 7, '제거': 7, '핵': 7, '수': 6, '볼턴': 5, '대북': 5, '제재': 5, '해제': 5, '등': 5, '관': 5, '핵무기': 5, '방안': 5, '무기': 5, '단계': 4, '대통령': 4, '행정부': 4, '보좌': 4, '장관': 4, '검증': 4, '를': 4, '우라늄': 4, '농축': 4, '고': 4, '함': 4, '및': 4, '합의': 4, '방식': 4, '요구': 3, '다음': 3, '빅딜': 3, '외교': 3, '안보': 3, '이': 3, '첫': 3, '제공': 3, '우선': 3, '폐기': 3, '반출': 3, '시설': 3, '보유': 3, '거론': 3, '살상': 3, '정상회담': 3, '핵물질': 3, '예상': 3, '우리': 3, '지원': 3, '조치': 2, '기간': 2, '압축': 2, '밑그림': 2, '소개': 2, '구체': 2, '김정은': 2, '국무위원': 2, '사진': 2, '달': 2, '싱가포르': 2, '간': 2, '회담': 2, '가운데': 2, '핵심': 2, '통해': 2, '대해': 2, '임기': 2, '마지막': 2, '국제사회': 2, '투자': 2, '각종': 2, '수교': 2, '평화협정': 2, '체결': 2, '내용': 2, '마이크': 2, '국무장관': 2, '시한': 2, '불가': 2, '역적': 2, '플루토늄': 2, '능력': 2, '주도': 2, '대량': 2, '모두': 2, '정책': 2, '인터뷰': 2, '의지': 2, '핵탄두': 2, '일부': 2, '면': 2, '말': 2, '그': 2, '정부': 2, '차원': 2, '해석': 2, '과': 2, '내': 2, '대한': 2, '동의': 2, '센터': 2, '문의': 2, '거래': 1, '연일': 1, '답변': 1, '안해': 1, '워싱턴': 1, '자료': 1, '조준형': 1, '도널드': 1, '세기': 1, '윤곽': 1, '인사': 1, '입': 1, '반응': 1, '지금': 1, '발언': 1, '종합': 1, '골자': 1, '사실': 1, '해인': 1, '달성': 1, '경협': 1, '존': 1, '백악관': 1, '국가': 1, '서로': 1, '역할': 1, '분담': 1, '메시지': 1, '채찍': 1, '방점': 1, '때': 1, '당근': 1, '현지': 1, '시간': 1, '영구': 1, '위해': 1, '재': 1, '처리': 1, '한편': 1, '제시': 1, '더욱이': 1, '해체': 1, '것임': 1, '매우': 1, '원료': 1, '생산': 1, '조기': 1, '한마디': 1, '손': 1, '무장': 1, '생화학': 1, '압박': 1, '미래': 1, '파기': 1, '정': 1, '최근': 1, '방북': 1, '동행': 1, '브라이언': 1, '훅': 1, '국무부': 1, '선임': 1, '기획': 1, '방송': 1, '내인': 1, '입장': 1, '무력': 1, '대륙간탄도미사일': 1, '중': 1, '개월': 1, '안': 1, '밖': 1, '논의': 1, '중인': 1, '절차': 1, '온': 1, '초장': 1, '국외': 1, '진정': 1, '보이': 1, '그래픽': 1, '주요': 1, '의제': 1, '박영석': 1, '역사상': 1, '린다': 1, '언론': 1, '대로': 1, '정권': 1, '교체': 1, '추구': 1, '점도': 1, '재차': 1, '강조': 1, '안전': 1, '보장': 1, '안전보장': 1, '불가침': 1, '의사': 1, '서면': 1, '확인': 1, '보고': 1, '만약': 1, '완화': 1, '더': 1, '라며': 1, '경제': 1, '인': 1, '센티': 1, '브': 1, '측면': 1, '플러스': 1, '알파': 1, '인도': 1, '제외': 1, '직접': 1, '제': 1, '국': 1, '기업': 1, '진출': 1, '독자': 1, '자본': 1, '기술': 1, '길': 1, '뜻': 1, '의사결정': 1, '영향력': 1, '활용': 1, '국제통화기금': 1, '세계': 1, '은행': 1, '융자': 1, '사업': 1, '롭': 1, '주목': 1, '주장': 1, '동시': 1, '해법': 1, '당신': 1, '이전': 1, '계속': 1, '성과': 1, '동시성': 1, '배제': 1, '최대한': 1, '크게': 1, '선호': 1, '음': 1, '시사': 1, '요한': 1, '또': 1, '최대': 1, '허들': 1, '경우': 1, '앞': 1, '제출': 1, '고서': 1, '수준': 1, '미신': 1, '일': 1, '진통': 1, '게': 1, '가의': 1, '체적': 1, '신범철': 1, '아산': 1, '연구원': 1, '통일': 1, '전체': 1, '목표': 1, '아래': 1, '효율': 1, '위': 1, '순위': 1, '설정': 1, '며': 1, '실현': 1, '접근': 1, '생각': 1, '신': 1, '가장': 1, '미사일': 1, '먼저': 1, '장비': 1, '데이터': 1, '인력': 1, '기타': 1, '모든': 1, '위협': 1, '이내': 1, '초기': 1, '지연': 1, '사전': 1, '차단': 1, '유지': 1, '방법': 1, '강': 1, '구한': 1, '평가': 1, '부연': 1, '은닉': 1, '프로그램': 1, '그것': 1, '규모': 1, '의': 1, '구심': 1, '해소': 1, '여부': 1, '속도': 1, '결정': 1, '파트너': 1, '기사': 1, '제보': 1, '생활': 1, '최신': 1, '트렌드': 1, '구매': 1})
# [('북한', 27), ('것', 19), ('미국', 13), ('비핵화', 12), ('이행', 9), ('북미', 9), ('트럼프', 8), ('폼페이', 7), ('오', 7), ('제거', 7), ('핵', 7), ('수', 6), ('볼턴', 5), ('대북', 5), ('제재', 5), ('해제', 5), ('등', 5), ('관', 5), ('핵무기', 5), ('방안', 5)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = '/Users/jehoonchae/Dropbox/Pycharm/NanumGothic.otf' # For Korean characters
# 한국어의 경우에는 폰트를 명확히 정해줘야 한다.

# %%
noun_text = ''
for word in Noun_words:
    noun_text = noun_text + ' ' + word

# %%
noun_text
# Out:
# ' 단계 조치 요구 이행 기간 압축 거래 폼페이 오 볼턴 연일 밑그림 소개 구체 답변 안해 트럼프 대통령 김정은 북한 국무위원 워싱턴 자료 사진 조준형 다음 달 싱가포르 도널드 트럼프 대통령 김정은 국무위원 간 세기 회담 가운데 북미 빅딜 윤곽 밑그림 트럼프 행정부 외교 안보 핵심 인사 입 통해 소개 이 대해 북한 구체 반응 지금 이 발언 종합 북미 빅딜 골자 트럼프 대통령 첫 임기 사실 마지막 해인 북한 비핵화 달성 미국 국제사회 대북 투자 경협 각종 제재 해제 북미 수교 평화협정 체결 등 내용 것 트럼프 행정부 존 볼턴 백악관 국가 안보 보좌 관 마이크 폼페이 오 국무장관 서로 역할 분담 대북 메시지 볼턴 보좌 관 채찍 비핵화 방점 폼페이 오 장관 비핵화 때 제공 당근 시한 우선 볼턴 보좌 관 현지 시간 북한 영구 검증 불가 역적 비핵화 를 위해 북한 우라늄 농축 플루토늄 재 처리 능력 제거 한편 핵무기 폐기 미국 반출 방안 제시 더욱이 핵무기 해체 미국 주도 것임 매우 고 핵무기 원료 플루토늄 농축 우라늄 생산 시설 제거 것 북한 보유 핵무기 조기 폐기 미국 방안 한마디 미국 손 북한 핵 무장 해제 것 요구 것 볼턴 보좌 관 핵무기 생화학 무기 거론 대량 살상 무기 를 모두 압박 트럼프 행정부 북한 보유 핵 미래 핵 모두 파기 조치 시한 정 최근 마이크 폼페이 오 국무장관 방북 동행 브라이언 훅 국무부 선임 정책 기획 관 방송 인터뷰 북한 의지 트럼프 대통령 첫 임기 내인 북한 불가 역적 비핵화 입장 가운데 북미 정상회담 북한 핵 무력 핵심 핵탄두 핵물질 대륙간탄도미사일 중 일부 개월 안 북한 밖 반출 방안 논의 중인 것 비핵화 마지막 단계 폐기 절차 것 예상 온 보유 핵 일부 초장 국외 반출 함 비핵화 진정 보이 것 미국 요구 수 그래픽 북미 정상회담 주요 의제 박영석 북한 미국 역사상 첫 정상회담 다음 달 싱가포르 린다 폼페이 오 장관 언론 인터뷰 미국 대로 북한 비핵화 이행 면 북한 정권 교체 추구 점도 재차 강조 우리 안전 보장 제공 것 말 안전보장 불가침 의사 서면 확인 북미 수교 및 평화협정 체결 등 것 외교 보고 폼페이 오 장관 만약 우리 비핵화 제재 완화 그 더 것 것 라며 경제 인 센티 브 측면 대북 제재 해제 플러스 알파 거론 인도 지원 제외 정부 차원 직접 대북 지원 미국 제 국 기업 북한 진출 및 투자 각종 미국 독자 제재 해제 함 북한 자본 기술 길 뜻 해석 미국 의사결정 영향력 활용 국제통화기금 과 세계 은행 등 대북 융자 사업 롭 수 방안 것 트럼프 행정부 내 북한 대한 정부 차원 지원 거론 주목 폼페이 오 장관 북미 합의 이행 방식 면 북한 주장 단계 동시 해법 대해 당신 를 우리 를 방식 이전 방식 계속 고 이행 단계 성과 동시성 배제 수 합의 이행 기간 최대한 압축 함 크게 방식 선호 음 시사 것 해석 이 방안 우선 북한 동의 요한 또 북한 동의 최대 허들 검증 것 예상 북미 간 비핵화 합의 경우 앞 북한 제출 핵 고서 내용 검증 수준 미신 시설 검증 수 합의 이행 일 진통 것 게 외교 가의 체적 예상 신범철 아산 정책 연구원 안보 통일 센터 미국 북한 살상 무기 능력 전체 제거 목표 아래 효율 이행 위 우선 순위 설정 것 며 북한 비핵화 의지 실현 접근 생각 고 말 신 센터 가장 핵물질 핵탄두 미사일 먼저 제거 그 다음 핵 시설 장비 데이터 인력 기타 대량 살상 무기 등 제거 것 모든 위협 이내 제거 수 핵물질 무기 초기 제거 함 북한 제재 해제 비핵화 이행 지연 사전 차단 주도 유지 방법 강 구한 것 평가 고 부연 은닉 우라늄 농축 프로그램 과 그것 통해 북한 농축 우라늄 규모 등 대한 미국 국제사회 의 구심 북한 해소 수 빅딜 이행 여부 및 속도 결정 것 북미 회담 파트너 제공 기사 제보 및 문의 내 생활 최신 트렌드 사진 구매 문의'

# %%
wordcloud = WordCloud(max_font_size=60, relative_scaling=.5, font_path=FONT_PATH).generate(noun_text) 
# generate() 는 하나의 string value를 입력 받음

# %%
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
